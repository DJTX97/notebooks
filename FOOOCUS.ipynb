# %%
#@title Prevent disconnections
# %%html
<audio src="https://oobabooga.github.io/silence.m4a" controls>

# %%
#@title Main Code
# %cd /content
# !apt install aria2
# !pip install pygit2==1.15.1
# !git clone https://github.com/lllyasviel/Fooocus.git

# %%
# @title Select Preset

def create_lora_preset(loras:dict):

    defaults = []

    for key, _ in loras.items():
        defaults.append([False, key, 0.5])


    return {
        "default_loras": defaults,
        "lora_downloads": loras
    }

KEY = ""  # @param {type:"string"}
KEY = "token=" + KEY.strip()

LORAS = create_lora_preset({
    "futanarimix.safetensors": f"https://civitai.com/api/download/models/398019?{KEY}",
    "twinkle_sex_furry.safetensors": f"https://civitai.com/api/download/models/403159?{KEY}",
    "Fat_Ginger_Girl.safetensors": f"https://civitai.com/api/download/models/396117?type=Model&format=SafeTensor&{KEY}",
    "velmaXL.safetensors": f"https://civitai.com/api/download/models/440485?type=Model&format=SafeTensor&{KEY}",
    "melascula.safetensors": f"https://civitai.com/api/download/models/435770?type=Model&format=SafeTensor&{KEY}",
    "orihime.safetensors": f"https://civitai.com/api/download/models/802815?type=Model&format=SafeTensor&{KEY}",
    "NaVi_Race_Avatar_JC_PXL_Leaf1.safetensors": f"https://civitai.com/api/download/models/935046?type=Model&format=SafeTensor&{KEY}",
    "Elizabeth_Dragon_from_Shrek_PonyXL.safetensors":f"https://civitai.com/models/758353/elizabeth-dragon-from-shrek-ponyxl&{KEY}",
    "Sculpture.safetensors":f"https://civitai.com/api/download/models/714222?type=Model&format=SafeTensor&{KEY}",
    "mcnsfwv7_8dim_pdxl.safetensors":f"https://civitai.com/api/download/models/488456?type=Model&format=SafeTensor&{KEY}",
    "Female_Argonian.safetensors":f"https://civitai.com/api/download/models/438968?type=Model&format=SafeTensor&{KEY}",
    "Skyrim_Khajiit.safetensors":f"https://civitai.com/api/download/models/484174?type=Model&format=SafeTensor&{KEY}",
    "Erotic_Alien_Anatomy.safetensors":f"https://civitai.com/models/675488/alien-anatomy&{KEY}",
    "Sqoon_Style__Pony_XL.safetensors":f"https://civitai.com/models/787484/sqoon-style-or-pony-xl&{KEY}",
    "grey_alien.safetensors":f"https://civitai.com/models/792469/little-grey-alien-flux-sdxl&{KEY}"
})

PRESETS = {
    "mklan_nsfw_anime_223": {
        "default_model": "mklan_hentai_223.safetensors",
        "default_loras": LORAS["default_loras"],
        "default_cfg_scale": 7.0,
        "default_sample_sharpness": 2.0,
        "default_sampler": "dpmpp_2m_sde_gpu",
        "default_scheduler": "karras",
        "default_performance": "Speed",
        "default_aspect_ratio": "832*1216",
        "default_prompt": "",
        "default_prompt_negative": "low quality, key, trademark, signature, watermark",
        "default_styles": [],
        "checkpoint_downloads": {
        "mklan_hentai_223.safetensors": f"https://civitai.com/api/download/models/439047?{KEY}",
        },
        "lora_downloads": LORAS["lora_downloads"]
    },

    "mklan_nsfw_anime_nextgenV4": {
        "default_model": "mklanANIMEHentai_nextgenV4.safetensors",
        "default_loras": LORAS["default_loras"],
        "default_cfg_scale": 7.0,
        "default_sample_sharpness": 2.0,
        "default_sampler": "dpmpp_2m_sde_gpu",
        "default_scheduler": "karras",
        "default_performance": "Speed",
        "default_aspect_ratio": "832*1216",
        "default_prompt": "",
        "default_prompt_negative": "low quality, key, trademark, signature, watermark",
        "default_styles": [],
        "checkpoint_downloads": {
        "mklanANIMEHentai_nextgenV4.safetensors": f"https://civitai.com/api/download/models/812350?type=Model&format=SafeTensor&size=pruned&fp=fp16&{KEY}",
        },
        "lora_downloads": LORAS["lora_downloads"]
    },

    "deepDarkHentaiMixNSFW_v61Hybrid": {
        "default_model": "deepDarkHentaiMixNSFW_v61Hybrid.safetensors",
        "default_loras": LORAS["default_loras"],
        "default_cfg_scale": 7.0,
        "default_sample_sharpness": 2.0,
        "default_sampler": "dpmpp_2m_sde_gpu",
        "default_scheduler": "karras",
        "default_performance": "Speed",
        "default_aspect_ratio": "832*1216",
        "default_prompt": "",
        "default_prompt_negative": "low quality, key, trademark, signature, watermark",
        "default_styles": [],
        "checkpoint_downloads": {
        "deepDarkHentaiMixNSFW_v61Hybrid.safetensors": f"https://civitai.com/api/download/models/634653?type=Model&format=SafeTensor&size=pruned&fp=fp16&{KEY}",
        },
        "lora_downloads": LORAS["lora_downloads"]
    },

    "waiANIHENTAIPONYXL_v60": {
        "default_model": "waiANIHENTAIPONYXL_v60.safetensors",
        "default_loras": LORAS["default_loras"],
        "default_cfg_scale": 7.0,
        "default_sample_sharpness": 2.0,
        "default_sampler": "dpmpp_2m_sde_gpu",
        "default_scheduler": "karras",
        "default_performance": "Speed",
        "default_aspect_ratio": "832*1216",
        "default_prompt": "",
        "default_prompt_negative": "low quality, key, trademark, signature, watermark",
        "default_styles": [],
        "checkpoint_downloads": {
        "waiANIHENTAIPONYXL_v60.safetensors": f"https://civitai.com/api/download/models/952743?type=Model&format=SafeTensor&size=pruned&fp=fp16&{KEY}",
        },
        "lora_downloads": LORAS["lora_downloads"]
    },

    "novaCartoon_v10": {
        "default_model": "novaCartoon_v10.safetensors",
        "default_loras": LORAS["default_loras"],
        "default_cfg_scale": 7.0,
        "default_sample_sharpness": 2.0,
        "default_sampler": "dpmpp_2m_sde_gpu",
        "default_scheduler": "karras",
        "default_performance": "Speed",
        "default_aspect_ratio": "832*1216",
        "default_prompt": "",
        "default_prompt_negative": "low quality, key, trademark, signature, watermark",
        "default_styles": [],
        "checkpoint_downloads": {
        "novaCartoon_v10.safetensors": f"https://civitai.com/api/download/models/821389?type=Model&format=SafeTensor&size=pruned&fp=fp16&{KEY}",
        },
        "lora_downloads": LORAS["lora_downloads"]
    },
}


CHOICE = "mklan_nsfw_anime_223"  #@param ["mklan_nsfw_anime_223", "mklan_nsfw_anime_nextgenV4", "deepDarkHentaiMixNSFW_v61Hybrid", "waiANIHENTAIPONYXL_v60", "novaCartoon_v10"]

# %%
#@title Download Preset
import json

DATA = {
    "default_model": PRESETS[CHOICE]["default_model"],
    "default_refiner": "None",
    "default_refiner_switch": 0.5,
    "default_loras": PRESETS[CHOICE]["default_loras"],
    "default_cfg_scale": PRESETS[CHOICE]["default_cfg_scale"],
    "default_sample_sharpness": PRESETS[CHOICE]["default_sample_sharpness"],
    "default_sampler": PRESETS[CHOICE]["default_sampler"],
    "default_scheduler": PRESETS[CHOICE]["default_scheduler"],
    "default_performance": "Speed",
    "default_prompt": PRESETS[CHOICE]["default_prompt"],
    "default_prompt_negative": PRESETS[CHOICE]["default_prompt_negative"],
    "default_styles": PRESETS[CHOICE]["default_styles"],
    "default_aspect_ratio": PRESETS[CHOICE]["default_aspect_ratio"],
    "checkpoint_downloads": {},
    "embeddings_downloads": {},
    "lora_downloads": {},
}

# %cd /content/Fooocus/presets

with open(f"{CHOICE}.json", 'w') as preset:
    json.dump(DATA, preset, indent=4)

# %cd /content/Fooocus/models

CHECKPOINT_DOWNLOAD_FILE = "aria2-checkpoint-list.txt"
CHECKPOINT_PATH = "/content/Fooocus/models/checkpoints"
with open(CHECKPOINT_DOWNLOAD_FILE, "w") as file:
    for checkpoint in list(PRESETS[CHOICE]["checkpoint_downloads"].items()):
        file.write(f"{checkpoint[1]}\n out={checkpoint[0]}\n")

LORA_DOWNLOAD_FILE = "aria2-lora-list.txt"
LORA_PATH = "/content/Fooocus/models/loras"
with open(LORA_DOWNLOAD_FILE, "w") as file:
    for lora in list(PRESETS[CHOICE]["lora_downloads"].items()):
        file.write(f"{lora[1]}\n out={lora[0]}\n")

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --summary-interval=5 --input-file=$CHECKPOINT_DOWNLOAD_FILE -d $CHECKPOINT_PATH
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --summary-interval=5 --input-file=$LORA_DOWNLOAD_FILE -d $LORA_PATH

# !rm $CHECKPOINT_DOWNLOAD_FILE
# !rm $LORA_DOWNLOAD_FILE

# %%
#@title LAUNCH!
# %cd /content/Fooocus

# !python entry_with_update.py --share --always-high-vram --theme dark --preset $CHOICE
